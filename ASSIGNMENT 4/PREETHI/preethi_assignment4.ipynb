# %% [markdown]
# IMPORTING THE LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
df = pd.read_csv('/content/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ..., 100,   2,  93],
#        [  0,   0,   0, ..., 743,   4, 354],
#        [  0,   0,   0, ...,   3, 398,  90],
#        ...,
#        [  0,   0,   0, ...,  15,  89,  43],
#        [  0,   0,   0, ...,  80,  32, 255],
#        [  0,   0,   0, ..., 389,  40, 179]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'or',
#  27: 'do',
#  28: 'at',
#  29: "i'm",
#  30: 'can',
#  31: 'get',
#  32: 'be',
#  33: 'if',
#  34: 'ur',
#  35: 'will',
#  36: 'just',
#  37: 'with',
#  38: 'no',
#  39: 'we',
#  40: 'this',
#  41: '4',
#  42: 'gt',
#  43: 'lt',
#  44: 'when',
#  45: 'up',
#  46: 'ok',
#  47: 'from',
#  48: 'out',
#  49: 'how',
#  50: 'free',
#  51: 'go',
#  52: 'what',
#  53: 'all',
#  54: 'know',
#  55: 'then',
#  56: 'good',
#  57: 'like',
#  58: 'come',
#  59: 'am',
#  60: 'got',
#  61: 'day',
#  62: 'was',
#  63: 'its',
#  64: 'time',
#  65: 'only',
#  66: 'love',
#  67: 'text',
#  68: 'he',
#  69: 'want',
#  70: 'there',
#  71: 'send',
#  72: 'going',
#  73: 'as',
#  74: 'need',
#  75: 'txt',
#  76: 'one',
#  77: 'by',
#  78: 'stop',
#  79: 'home',
#  80: "i'll",
#  81: 'r',
#  82: 'about',
#  83: 'lor',
#  84: 'back',
#  85: 'sorry',
#  86: 'see',
#  87: 'still',
#  88: 'today',
#  89: 'da',
#  90: 'reply',
#  91: 'k',
#  92: 'dont',
#  93: 'our',
#  94: 'n',
#  95: 'mobile',
#  96: 'take',
#  97: 'new',
#  98: 'tell',
#  99: 'please',
#  100: 'hi',
#  101: 'later',
#  102: 'any',
#  103: 'she',
#  104: 'been',
#  105: 'her',
#  106: 'here',
#  107: 'think',
#  108: 'week',
#  109: "don't",
#  110: 'pls',
#  111: 'some',
#  112: 'well',
#  113: 'they',
#  114: 'much',
#  115: 'did',
#  116: 'dear',
#  117: 'phone',
#  118: 'him',
#  119: 'claim',
#  120: 'where',
#  121: '1',
#  122: 'oh',
#  123: 'hope',
#  124: 'ì',
#  125: 'night',
#  126: 'has',
#  127: 'hey',
#  128: 'an',
#  129: 'great',
#  130: 'yes',
#  131: 'who',
#  132: 'happy',
#  133: 'give',
#  134: 'more',
#  135: 'way',
#  136: 'work',
#  137: 'too',
#  138: 'msg',
#  139: 'had',
#  140: 'make',
#  141: 'www',
#  142: 'prize',
#  143: 'should',
#  144: 'c',
#  145: 'wat',
#  146: 'number',
#  147: '3',
#  148: "it's",
#  149: 'e',
#  150: 'right',
#  151: 'really',
#  152: 'd',
#  153: 'amp',
#  154: 'after',
#  155: 'already',
#  156: 'doing',
#  157: 'tomorrow',
#  158: 'message',
#  159: 'cash',
#  160: 'im',
#  161: 'yeah',
#  162: 'life',
#  163: 'miss',
#  164: 'meet',
#  165: 'very',
#  166: 'said',
#  167: 'find',
#  168: 'won',
#  169: 'say',
#  170: 'every',
#  171: 'them',
#  172: 'thanks',
#  173: 'why',
#  174: 'cos',
#  175: 'babe',
#  176: 'win',
#  177: 'last',
#  178: 'would',
#  179: 'morning',
#  180: 'nokia',
#  181: '150p',
#  182: 'let',
#  183: 't',
#  184: 'anything',
#  185: 'lol',
#  186: 'keep',
#  187: 'care',
#  188: 'also',
#  189: 'urgent',
#  190: 'contact',
#  191: 'sure',
#  192: 'b',
#  193: 'ask',
#  194: 'us',
#  195: 'buy',
#  196: 'uk',
#  197: 'sent',
#  198: 'com',
#  199: 'around',
#  200: 'min',
#  201: 'soon',
#  202: 's',
#  203: 'feel',
#  204: 'something',
#  205: 'over',
#  206: 'again',
#  207: 'someone',
#  208: 'wait',
#  209: 'thing',
#  210: 'tone',
#  211: 'off',
#  212: 'next',
#  213: 'even',
#  214: 'before',
#  215: 'went',
#  216: 'were',
#  217: 'cant',
#  218: '5',
#  219: 'pick',
#  220: 'first',
#  221: "i've",
#  222: 'customer',
#  223: 'which',
#  224: 'service',
#  225: 'tonight',
#  226: 'sleep',
#  227: 'nice',
#  228: 'always',
#  229: 'per',
#  230: 'place',
#  231: 'could',
#  232: 'told',
#  233: '50',
#  234: "can't",
#  235: 'ya',
#  236: 'gonna',
#  237: 'other',
#  238: '16',
#  239: 'many',
#  240: 'chat',
#  241: 'help',
#  242: 'hello',
#  243: 'down',
#  244: 'his',
#  245: "that's",
#  246: 'ìï',
#  247: 'money',
#  248: 'friend',
#  249: 'sms',
#  250: 'co',
#  251: 'things',
#  252: 'fine',
#  253: 'x',
#  254: 'friends',
#  255: 'late',
#  256: 'coming',
#  257: "you're",
#  258: 'v',
#  259: 'wan',
#  260: 'people',
#  261: 'guaranteed',
#  262: '18',
#  263: 'wish',
#  264: 'getting',
#  265: 'mins',
#  266: 'holiday',
#  267: 'gud',
#  268: 'may',
#  269: 'name',
#  270: 'heart',
#  271: 'leave',
#  272: '6',
#  273: 'haha',
#  274: 'year',
#  275: 'done',
#  276: 'special',
#  277: 'live',
#  278: 'better',
#  279: 'try',
#  280: 'class',
#  281: 'talk',
#  282: 'finish',
#  283: 'same',
#  284: 'dun',
#  285: 'use',
#  286: 'waiting',
#  287: 'stuff',
#  288: 'cs',
#  289: 'trying',
#  290: 'yet',
#  291: 'yup',
#  292: 'enjoy',
#  293: 'ready',
#  294: 'long',
#  295: 'man',
#  296: 'draw',
#  297: 'thought',
#  298: 'ill',
#  299: 'few',
#  300: 'lunch',
#  301: 'smile',
#  302: 'line',
#  303: 'end',
#  304: 'thk',
#  305: 'days',
#  306: 'house',
#  307: 'meeting',
#  308: 'bit',
#  309: 'job',
#  310: 'because',
#  311: 'thats',
#  312: 'best',
#  313: 'chance',
#  314: 'cool',
#  315: 'never',
#  316: 'god',
#  317: 'wanna',
#  318: "didn't",
#  319: 'problem',
#  320: 'month',
#  321: 'shows',
#  322: 'car',
#  323: 'mind',
#  324: 'being',
#  325: 'person',
#  326: 'half',
#  327: 'guess',
#  328: 'å£1',
#  329: 'play',
#  330: 'dinner',
#  331: 'wk',
#  332: 'offer',
#  333: 'big',
#  334: 'ever',
#  335: 'having',
#  336: 'video',
#  337: 'lot',
#  338: 'real',
#  339: 'll',
#  340: 'dat',
#  341: 'latest',
#  342: 'camera',
#  343: 'room',
#  344: '7',
#  345: 'word',
#  346: 'than',
#  347: '1st',
#  348: 'speak',
#  349: 'sir',
#  350: 'yo',
#  351: 'nothing',
#  352: 'receive',
#  353: 'eat',
#  354: 'liao',
#  355: 'den',
#  356: 'ah',
#  357: 'easy',
#  358: 'jus',
#  359: 'into',
#  360: 'might',
#  361: 'watching',
#  362: 'world',
#  363: 'account',
#  364: 'part',
#  365: 'landline',
#  366: 'start',
#  367: 'check',
#  368: 'shit',
#  369: 'actually',
#  370: 'bt',
#  371: 'dunno',
#  372: 'two',
#  373: 'thanx',
#  374: 'pay',
#  375: 'ringtone',
#  376: 'tv',
#  377: 'å£1000',
#  378: 'y',
#  379: 'office',
#  380: 'weekend',
#  381: 'awarded',
#  382: 'bed',
#  383: 'quite',
#  384: 'lar',
#  385: 'minutes',
#  386: 'wont',
#  387: "he's",
#  388: 'hear',
#  389: 'early',
#  390: 'watch',
#  391: '9',
#  392: 'luv',
#  393: 'cost',
#  394: 'apply',
#  395: 'girl',
#  396: 'rate',
#  397: 'bad',
#  398: 'didnt',
#  399: 'princess',
#  400: 'reach',
#  401: 'between',
#  402: 'sweet',
#  403: 'another',
#  404: 'orange',
#  405: 'plan',
#  406: 'called',
#  407: '10',
#  408: '150ppm',
#  409: 'forgot',
#  410: 'guys',
#  411: 'baby',
#  412: 'shall',
#  413: 'po',
#  414: 'box',
#  415: 'once',
#  416: 'does',
#  417: 'shopping',
#  418: 'working',
#  419: 'maybe',
#  420: 'looking',
#  421: 'code',
#  422: 'enough',
#  423: 'while',
#  424: 'sat',
#  425: 'wife',
#  426: 'made',
#  427: 'face',
#  428: 'probably',
#  429: 'fun',
#  430: 'able',
#  431: 'bus',
#  432: 'little',
#  433: 'xxx',
#  434: 'award',
#  435: '2nd',
#  436: 'collect',
#  437: 'aight',
#  438: '000',
#  439: 'look',
#  440: 'school',
#  441: 'pain',
#  442: 'xmas',
#  443: 'sexy',
#  444: 'mob',
#  445: 'tones',
#  446: 'okay',
#  447: 'boy',
#  448: 'texts',
#  449: 'thank',
#  450: 'dis',
#  451: 'm',
#  452: 'put',
#  453: 'town',
#  454: 'wanted',
#  455: 'came',
#  456: "there's",
#  457: 'anyway',
#  458: 'hour',
#  459: 'network',
#  460: 'most',
#  461: 'everything',
#  462: 'havent',
#  463: 'mail',
#  464: 'wake',
#  465: 'must',
#  466: 'without',
#  467: 'those',
#  468: '8',
#  469: 'hair',
#  470: 'tmr',
#  471: 'years',
#  472: 'away',
#  473: 'saw',
#  474: 'plus',
#  475: 'plz',
#  476: "how's",
#  477: "we're",
#  478: 'collection',
#  479: 'evening',
#  480: 'alright',
#  481: 'worry',
#  482: 'pa',
#  483: 'until',
#  484: 'times',
#  485: 'asked',
#  486: 'left',
#  487: 'gift',
#  488: 'price',
#  489: 'means',
#  490: 'abt',
#  491: 'though',
#  492: 'kiss',
#  493: 'selected',
#  494: 'since',
#  495: 'afternoon',
#  496: 'wif',
#  497: 'leh',
#  498: 'details',
#  499: 'important',
#  500: 'de',
#  501: 'online',
#  502: 'sch',
#  503: 'guy',
#  504: 'yesterday',
#  505: 'bring',
#  506: 'bonus',
#  507: 'beautiful',
#  508: 'remember',
#  509: 'attempt',
#  510: 'goin',
#  511: 'fuck',
#  512: 'show',
#  513: 'both',
#  514: 'double',
#  515: 'lei',
#  516: 'driving',
#  517: 'birthday',
#  518: 'hav',
#  519: 'hurt',
#  520: 'net',
#  521: 'g',
#  522: 'making',
#  523: 'dad',
#  524: 'decimal',
#  525: 'update',
#  526: 'else',
#  527: 'true',
#  528: 'comes',
#  529: 'valid',
#  530: 'yours',
#  531: 'address',
#  532: 'makes',
#  533: 'haf',
#  534: 'http',
#  535: 'calls',
#  536: 're',
#  537: 'juz',
#  538: '10p',
#  539: 'national',
#  540: 'sad',
#  541: 'dude',
#  542: '500',
#  543: 'busy',
#  544: 'question',
#  545: 'answer',
#  546: 'sleeping',
#  547: 'tried',
#  548: 'calling',
#  549: 'missed',
#  550: 'family',
#  551: 'delivery',
#  552: 'change',
#  553: 'wants',
#  554: 'run',
#  555: 'oso',
#  556: 'stay',
#  557: 'club',
#  558: 'order',
#  559: 'friendship',
#  560: 'id',
#  561: '8007',
#  562: 'points',
#  563: 'together',
#  564: 'colour',
#  565: 'goes',
#  566: 'coz',
#  567: 'food',
#  568: "we'll",
#  569: 'smiling',
#  570: 'lose',
#  571: 'tot',
#  572: 'hot',
#  573: 'pounds',
#  574: 'these',
#  575: 'words',
#  576: 'tomo',
#  577: 'å£5000',
#  578: 'sae',
#  579: 'shop',
#  580: 'dreams',
#  581: 'set',
#  582: 'full',
#  583: 'hours',
#  584: 'saying',
#  585: 'says',
#  586: 'wot',
#  587: 'private',
#  588: 'poly',
#  589: 'ard',
#  590: 'feeling',
#  591: 'date',
#  592: 'join',
#  593: 'entry',
#  594: 'todays',
#  595: 'rite',
#  596: 'awesome',
#  597: 'game',
#  598: 'story',
#  599: 'bored',
#  600: 'walk',
#  601: 'mean',
#  602: 'test',
#  603: 'missing',
#  604: 'eve',
#  605: 'book',
#  606: 'okie',
#  607: 'either',
#  608: 'simple',
#  609: 'await',
#  610: 'pm',
#  611: 'alone',
#  612: 'weekly',
#  613: 'choose',
#  614: 'nite',
#  615: 'til',
#  616: 'row',
#  617: 'drive',
#  618: 'pics',
#  619: 'top',
#  620: 'wen',
#  621: 'final',
#  622: '86688',
#  623: 'started',
#  624: 'ring',
#  625: "haven't",
#  626: 'pic',
#  627: 'music',
#  628: 'vouchers',
#  629: 'brother',
#  630: 'yourself',
#  631: 'gr8',
#  632: 'messages',
#  633: 'neva',
#  634: 'old',
#  635: 'till',
#  636: 'happen',
#  637: 'w',
#  638: 'kind',
#  639: 'dating',
#  640: 'post',
#  641: 'gone',
#  642: 'finished',
#  643: 'trip',
#  644: 'info',
#  645: "what's",
#  646: 'wil',
#  647: 'statement',
#  648: 'each',
#  649: 'charge',
#  650: 'open',
#  651: 'land',
#  652: 'took',
#  653: 'congrats',
#  654: 'pobox',
#  655: 'wid',
#  656: 'games',
#  657: 'å£100',
#  658: 'movie',
#  659: 'touch',
#  660: 'sounds',
#  661: "c's",
#  662: 'aft',
#  663: 'leaving',
#  664: 'mobileupd8',
#  665: 'worth',
#  666: 'unsubscribe',
#  667: 'anytime',
#  668: 'frnd',
#  669: 'ha',
#  670: 'company',
#  671: 'takes',
#  672: 'weeks',
#  673: 'email',
#  674: 'lucky',
#  675: 'whats',
#  676: 'news',
#  677: 'å£2000',
#  678: 'drink',
#  679: 'identifier',
#  680: 'expires',
#  681: 'mine',
#  682: 'sister',
#  683: '12hrs',
#  684: '750',
#  685: 'services',
#  686: 'pub',
#  687: 'opt',
#  688: "won't",
#  689: 'huh',
#  690: 'close',
#  691: 'college',
#  692: 'mates',
#  693: 'fucking',
#  694: 'ltd',
#  695: 'chikku',
#  696: 'taking',
#  697: 'nt',
#  698: 'lets',
#  699: "''",
#  700: 'minute',
#  701: 'cause',
#  702: 'second',
#  703: '08000839402',
#  704: 'xx',
#  705: 'lots',
#  706: 'saturday',
#  707: 'available',
#  708: 'noe',
#  709: 'prob',
#  710: 'earlier',
#  711: 'card',
#  712: 'head',
#  713: 'thinking',
#  714: 'boytoy',
#  715: 'rs',
#  716: 'å£3',
#  717: 'tho',
#  718: 'auction',
#  719: 'darlin',
#  720: 'forget',
#  721: 'tel',
#  722: 'telling',
#  723: 'needs',
#  724: 'treat',
#  725: 'sis',
#  726: '100',
#  727: 'finally',
#  728: '11',
#  729: 'smth',
#  730: 'far',
#  731: 'tc',
#  732: 'voucher',
#  733: 'believe',
#  734: 'gd',
#  735: '30',
#  736: "she's",
#  737: 'hows',
#  738: 'content',
#  739: 'light',
#  740: 'savamob',
#  741: 'freemsg',
#  742: 'pretty',
#  743: 'found',
#  744: 'chennai',
#  745: 'goodmorning',
#  746: "doesn't",
#  747: 'knw',
#  748: 'happened',
#  749: 'course',
#  750: 'fr',
#  751: 'break',
#  752: 'bank',
#  753: 'fancy',
#  754: 'loving',
#  755: 'suite342',
#  756: '2lands',
#  757: 'mate',
#  758: 'happiness',
#  759: 'anyone',
#  760: 'decided',
#  761: 'credit',
#  762: 'everyone',
#  763: '08000930705',
#  764: 'caller',
#  765: '03',
#  766: 'wonderful',
#  767: "you've",
#  768: 'outside',
#  769: 'å£250',
#  770: 'å£350',
#  771: 'parents',
#  772: 'å£2',
#  773: 'search',
#  774: 'smoke',
#  775: 'cum',
#  776: 'sun',
#  777: 'whatever',
#  778: 'angry',
#  779: 'sea',
#  780: 'offers',
#  781: 'welcome',
#  782: 'fast',
#  783: 'meant',
#  784: 'winner',
#  785: 'father',
#  786: 'john',
#  787: 'charged',
#  788: 'stupid',
#  789: 'through',
#  790: 'lesson',
#  791: 'ago',
#  792: 'type',
#  793: 'mum',
#  794: 'ac',
#  795: 'hmm',
#  796: 'mr',
#  797: 'reading',
#  798: 'currently',
#  799: 'o',
#  800: 'drop',
#  801: 'th',
#  802: 'ten',
#  803: 'quiz',
#  804: 'å£500',
#  805: 'read',
#  806: 'player',
#  807: 'unlimited',
#  808: 'camcorder',
#  809: 'friday',
#  810: '2003',
#  811: '800',
#  812: 'un',
#  813: 'understand',
#  814: 'side',
#  815: 'girls',
#  816: 'mobiles',
#  817: 'seeing',
#  818: 'hit',
#  819: 'wkly',
#  820: 'party',
#  821: 'nope',
#  822: 'wit',
#  823: 'log',
#  824: 'congratulations',
#  825: 'motorola',
#  826: 'etc',
#  827: 'visit',
#  828: 'reason',
#  829: 'ni8',
#  830: 'valued',
#  831: 'call2optout',
#  832: 'knew',
#  833: 'na',
#  834: 'listen',
#  835: 'couple',
#  836: 'whenever',
#  837: 'cut',
#  838: 'sunday',
#  839: 'confirm',
#  840: 'ass',
#  841: 'f',
#  842: 'christmas',
#  843: 'uncle',
#  844: 'felt',
#  845: 'asap',
#  846: 'met',
#  847: "'",
#  848: 'crazy',
#  849: 'p',
#  850: 'balance',
#  851: 'rental',
#  852: 'phones',
#  853: 'operator',
#  854: 'small',
#  855: 'secret',
#  856: 'bout',
#  857: 'fone',
#  858: 'red',
#  859: 'frm',
#  860: 'crave',
#  861: 'hard',
#  862: 'msgs',
#  863: 'correct',
#  864: 'computer',
#  865: 'carlos',
#  866: 'don',
#  867: '\x89û',
#  868: 'gotta',
#  869: 'redeemed',
#  870: 'their',
#  871: 'numbers',
#  872: 'slowly',
#  873: 'talking',
#  874: 'ugh',
#  875: "you'll",
#  876: 'eh',
#  877: 'gas',
#  878: 'least',
#  879: 'gym',
#  880: 'lost',
#  881: 'song',
#  882: 'yar',
#  883: 'b4',
#  884: 'wow',
#  885: 'hungry',
#  886: 'oredi',
#  887: 'direct',
#  888: 'frnds',
#  889: 'march',
#  890: 'case',
#  891: 'pass',
#  892: 'wonder',
#  893: 'feels',
#  894: 'luck',
#  895: '20',
#  896: '0800',
#  897: 'area',
#  898: 'fri',
#  899: 'thinks',
#  900: 'hand',
#  901: 'checking',
#  902: 'wishing',
#  903: 'sell',
#  904: 'age',
#  905: "i'd",
#  906: 'wrong',
#  907: 'poor',
#  908: 'wine',
#  909: 'callertune',
#  910: 'press',
#  911: 'blue',
#  912: 'mrng',
#  913: 'semester',
#  914: 'safe',
#  915: 'sound',
#  916: 'india',
#  917: 'dream',
#  918: 'yr',
#  919: 'pete',
#  920: 'eg',
#  921: 'point',
#  922: 'england',
#  923: 'somebody',
#  924: 'hmv',
#  925: 'invited',
#  926: 'swing',
#  927: 'ex',
#  928: 'mayb',
#  929: 'remove',
#  930: "isn't",
#  931: 'snow',
#  932: 'lovely',
#  933: 'txting',
#  934: 'usf',
#  935: 'ipod',
#  936: '04',
#  937: 'park',
#  938: 'hmmm',
#  939: 'rest',
#  940: 'drugs',
#  941: 'pray',
#  942: 'link',
#  943: 'wap',
#  944: 'picking',
#  945: 'kids',
#  946: 'surprise',
#  947: 'comp',
#  948: 'bathe',
#  949: 'own',
#  950: 'bath',
#  951: 'discount',
#  952: 'truth',
#  953: 'plans',
#  954: 'laptop',
#  955: 'otherwise',
#  956: 'ends',
#  957: 'questions',
#  958: 'used',
#  959: 'em',
#  960: 'clean',
#  961: "wasn't",
#  962: 'tired',
#  963: 'myself',
#  964: '00',
#  965: 'figure',
#  966: 'sub',
#  967: 'hold',
#  968: 'paper',
#  969: 'worried',
#  970: 'enter',
#  971: 'ans',
#  972: 'die',
#  973: 'bslvyl',
#  974: 'darren',
#  975: 'merry',
#  976: 'project',
#  977: 'hee',
#  978: 'asking',
#  979: 'possible',
#  980: 'del',
#  981: 'st',
#  982: 'gets',
#  983: 'monday',
#  984: 'download',
#  985: 'leaves',
#  986: '4u',
#  987: 'reached',
#  988: 'support',
#  989: 'loved',
#  990: 'al',
#  991: 'entered',
#  992: 'ringtones',
#  993: 'rock',
#  994: 'std',
#  995: 'hg',
#  996: 'rply',
#  997: 'getzed',
#  998: 'whole',
#  999: 'cheap',
#  1000: 'months',
#  ...}

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           262752
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 317,993
# Trainable params: 317,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 27s 713ms/step - loss: 0.4676 - accuracy: 0.8522 - val_loss: 0.3049 - val_accuracy: 0.8565
# Epoch 2/10
# 30/30 [==============================] - 12s 406ms/step - loss: 0.1957 - accuracy: 0.9456 - val_loss: 0.1215 - val_accuracy: 0.9789

# %%
lstm_model.save('sms.h5')

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0977 - accuracy: 0.9809

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.098
#   Accuracy: 0.981
